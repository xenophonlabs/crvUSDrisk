# %% [markdown]
# # Analyzing CEX Price Impact using CCXT
#
# Here we extract CCXT `trade` and `ohlcv` data to approximate the price impact of trades against centralized exchanges.

# %%
import ccxt as ccxt
from datetime import datetime, timedelta, timezone
from dotenv import load_dotenv
import os
import time
import json
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from src.utils.ccxtdatafetcher import CCXTDataFetcher
import asyncio

# %load_ext autoreload
# %autoreload 2

load_dotenv()
coinbase_pro_api_key = os.getenv("COINBASE_PRO_API_KEY")
coinbase_pro_api_secret = os.getenv("COINBASE_PRO_API_SECRET")
coinbase_pro_api_password = os.getenv("COINBASE_PRO_API_PWD")

# %%
datafetcher = CCXTDataFetcher(
    coinbase_pro_api_key, coinbase_pro_api_secret, coinbase_pro_api_password
)

# %%
df = pd.read_parquet("../data/trades/binance_ETH_USDC_1699592400.gzip")
cols = [
    "best_price_match",
    "timestamp",
    "aggregate_trade_id",
    "first_trade_id",
    "last_trade_id",
    "maker",
    "price",
    "quantity",
]
df[cols] = df["info"].apply(pd.Series)
df.drop(["info", "fees"], axis=1, inplace=True)
df.drop_duplicates(inplace=True)
print(df.shape)
df.head()
# Out:
# (24874, 17)
#                               timestamp    symbol        id order  type side  \
# datetime
# 2023-11-10T00:00:05.141Z  1699574405141  ETH/USDC  30737891  None  None  buy
# 2023-11-10T00:00:05.142Z  1699574405142  ETH/USDC  30737892  None  None  buy
# 2023-11-10T00:00:06.595Z  1699574406595  ETH/USDC  30737893  None  None  buy
# 2023-11-10T00:00:06.595Z  1699574406595  ETH/USDC  30737894  None  None  buy
# 2023-11-10T00:00:09.442Z  1699574409442  ETH/USDC  30737895  None  None  buy
#
#                          takerOrMaker          price  amount         cost  \
# datetime
# 2023-11-10T00:00:05.141Z         None  2121.37000000  0.3485   739.297445
# 2023-11-10T00:00:05.142Z         None  2121.37000000  2.0084  4260.559508
# 2023-11-10T00:00:06.595Z         None  2121.65000000  1.2453  2642.090745
# 2023-11-10T00:00:06.595Z         None  2121.65000000  1.1113  2357.789645
# 2023-11-10T00:00:09.442Z         None  2121.66000000  0.9629  2042.946414
#
#                            fee  best_price_match aggregate_trade_id  \
# datetime
# 2023-11-10T00:00:05.141Z  None              True           30737891
# 2023-11-10T00:00:05.142Z  None              True           30737892
# 2023-11-10T00:00:06.595Z  None              True           30737893
# 2023-11-10T00:00:06.595Z  None              True           30737894
# 2023-11-10T00:00:09.442Z  None              True           30737895
#
#                          first_trade_id last_trade_id  maker    quantity
# datetime
# 2023-11-10T00:00:05.141Z       32082305      32082305  False  0.34850000
# 2023-11-10T00:00:05.142Z       32082306      32082306  False  2.00840000
# 2023-11-10T00:00:06.595Z       32082307      32082307  False  1.24530000
# 2023-11-10T00:00:06.595Z       32082308      32082308  False  1.11130000
# 2023-11-10T00:00:09.442Z       32082309      32082309  False  0.96290000

# %% [markdown]
# # Computing Slippage
# <img src="../figs/random/binance_trade_description.png" alt="image" width="400"/>
#
# In the Binance data, each trade is a fill. A single trade might be broken up into multiple fills. Let `VWAP` be the volume-weighted average price for a trade, and let `p_{min}` be the minimum price paid for the first fill. The "price impact" paid by the trade can be thought of as `VWAP - p_{min}`, since `p_{min}` was the price at the top of the book when they placed their order, and `VWAP` is what they actually ended up paying (a higher price) for their desired trade size.
#
# To know which trades to group together, we set an arbitrary (but reasonable) time window within which we cluster trades.
#
# There will be some issues:
#
# - Fees are not just a function of trade size; each trader might have different fee tiers based on their previous volume, etc.
# -

# %%
cols = [
    "best_price_match",
    "timestamp",
    "",
    "first_trade_id",
    "last_trade_id",
    "maker",
    "price",
    "quantity",
]
df.astype({"aggregate_trade_id", int})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 cols = ["best_price_match", "timestamp", "", "first_trade_id", "last_trade_id", "maker", "price", "quantity"]
# ----> 2 df.astype({
#       3     "aggregate_trade_id", int
#       4 })
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/pandas/core/internals/blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:232, in astype_array_safe(values, dtype, copy, errors)
#     226     msg = (
#     227         f"Expected an instance of {dtype.__name__}, "
#     228         "but got the class instead. Try instantiating 'dtype'."
#     229     )
#     230     raise TypeError(msg)
# --> 232 dtype = pandas_dtype(dtype)
#     233 if isinstance(dtype, NumpyEADtype):
#     234     # Ensure we don't end up with a NumpyExtensionArray
#     235     dtype = dtype.numpy_dtype
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/pandas/core/dtypes/common.py:1636, in pandas_dtype(dtype)
#    1631     with warnings.catch_warnings():
#    1632         # GH#51523 - Series.astype(np.integer) doesn't show
#    1633         # numpy deprecation warning of np.integer
#    1634         # Hence enabling DeprecationWarning
#    1635         warnings.simplefilter("always", DeprecationWarning)
# -> 1636         npdtype = np.dtype(dtype)
#    1637 except SyntaxError as err:
#    1638     # np.dtype uses `eval` which can raise SyntaxError
#    1639     raise TypeError(f"data type '{dtype}' not understood") from err
#
# TypeError: Cannot interpret '{'aggregate_trade_id', <class 'int'>}' as a data type

# %%
df[df["last_trade_id"] == "32082314"]
# Out:
#                               timestamp    symbol        id order  type side  \
# datetime
# 2023-11-10T00:00:20.685Z  1699574420685  ETH/USDC  30737899  None  None  buy
#
#                          takerOrMaker          price  amount       cost   fee  \
# datetime
# 2023-11-10T00:00:20.685Z         None  2122.62000000  0.1055  223.93641  None
#
#                           best_price_match aggregate_trade_id first_trade_id  \
# datetime
# 2023-11-10T00:00:20.685Z              True           30737899       32082313
#
#                          last_trade_id  maker    quantity
# datetime
# 2023-11-10T00:00:20.685Z      32082314  False  0.10550000

# %%
df[df["last_trade_id"].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [timestamp, symbol, id, order, type, side, takerOrMaker, price, amount, cost, fee, best_price_match, aggregate_trade_id, first_trade_id, last_trade_id, maker, quantity]
# Index: []

# %%
symbol = "ETH/USD"
exchange = datafetcher.coinbasepro
since = exchange.parse8601("2023-11-10 00:00:00")
end = exchange.parse8601("2023-11-11 00:00:00")
cur = int(datetime.now(tz=timezone.utc).timestamp() * 1000)
end = min(end, cur) if end else cur
ohlcv = []

while since < end:
    try:
        new_ohlcv = exchange.fetch_ohlcv(symbol, timeframe="1m", since=since)
        if not len(new_ohlcv):
            break
        since = new_ohlcv[-1][0]
        ohlcv.extend(new_ohlcv)
    except ccxt.RateLimitExceeded:
        exchange.sleep(10000)
    except Exception:
        raise

df = datafetcher.ohlcv_to_df(ohlcv)
df.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1166 if buffer is not None:
# -> 1167     return self._sslobj.read(len, buffer)
#    1168 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/util/retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:539, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     538 except (BaseSSLError, OSError) as e:
# --> 539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     540     raise
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:371, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     370 if isinstance(err, SocketTimeout):
# --> 371     raise ReadTimeoutError(
#     372         self, url, f"Read timed out. (read timeout={timeout_value})"
#     373     ) from err
#     375 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.pro.coinbase.com', port=443): Read timed out. (read timeout=10)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/ccxt/base/exchange.py:587, in Exchange.fetch(self, url, method, headers, body)
#     586 try:
# --> 587     response = self.session.request(
#     588         method,
#     589         url,
#     590         data=body,
#     591         headers=request_headers,
#     592         timeout=int(self.timeout / 1000),
#     593         proxies=proxies,
#     594         verify=self.verify and self.validateServerSsl
#     595     )
#     596     # does not try to detect encoding
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/requests/adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='api.pro.coinbase.com', port=443): Read timed out. (read timeout=10)
#
# The above exception was the direct cause of the following exception:
#
# RequestTimeout                            Traceback (most recent call last)
# Cell In[24], line 12
#      10 while since < end:
#      11     try:
# ---> 12         new_ohlcv = exchange.fetch_ohlcv(symbol, timeframe="1m", since=since)
#      13         if not len(new_ohlcv):
#      14             break
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/ccxt/coinbasepro.py:924, in coinbasepro.fetch_ohlcv(self, symbol, timeframe, since, limit, params)
#     922     else:
#     923         request['end'] = self.iso8601(until)
# --> 924 response = self.publicGetProductsIdCandles(self.extend(request, params))
#     925 #
#     926 #     [
#     927 #         [1591514160,0.02507,0.02507,0.02507,0.02507,0.02816506],
#    (...)
#     930 #     ]
#     931 #
#     932 return self.parse_ohlcvs(response, market, timeframe, since, limit)
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/ccxt/base/types.py:28, in Entry.__init__.<locals>.unbound_method(_self, params)
#      27 def unbound_method(_self, params={}):
# ---> 28     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/ccxt/coinbasepro.py:1744, in coinbasepro.request(self, path, api, method, params, headers, body, config)
#    1743 def request(self, path, api='public', method='GET', params={}, headers=None, body=None, config={}):
# -> 1744     response = self.fetch2(path, api, method, params, headers, body, config)
#    1745     if not isinstance(response, str):
#    1746         if 'message' in response:
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/ccxt/base/exchange.py:3192, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    3190 self.last_request_body = request['body']
#    3191 self.last_request_url = request['url']
# -> 3192 return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#
# File ~/Desktop/root/xenophon/clients/curve/crvUSDrisk/venv/lib/python3.11/site-packages/ccxt/base/exchange.py:617, in Exchange.fetch(self, url, method, headers, body)
#     615 except Timeout as e:
#     616     details = ' '.join([self.id, method, url])
# --> 617     raise RequestTimeout(details) from e
#     619 except TooManyRedirects as e:
#     620     details = ' '.join([self.id, method, url])
#
# RequestTimeout: coinbasepro GET https://api.pro.coinbase.com/products/ETH-USD/candles?granularity=60&start=2023-11-10T23%3A06%3A00.000Z&end=2023-11-11T04%3A05%3A00.000Z

# %%
datetime.fromtimestamp(ohlcv[-1][0] / 1000, tz=timezone.utc)
# Out:
# datetime.datetime(2023, 11, 9, 4, 59, tzinfo=datetime.timezone.utc)

# %%
df.tail()
# Out:
#                          timestamp     open     high      low    close  \
# timestamp
# 2023-11-09 04:55:00  1699505700000  1924.01  1924.69  1923.85  1924.59
# 2023-11-09 04:56:00  1699505760000  1924.60  1925.08  1924.32  1924.33
# 2023-11-09 04:57:00  1699505820000  1924.33  1925.45  1924.33  1925.38
# 2023-11-09 04:58:00  1699505880000  1925.43  1926.43  1925.42  1925.70
# 2023-11-09 04:59:00  1699505940000  1925.95  1926.06  1924.31  1924.43
#
#                         volume
# timestamp
# 2023-11-09 04:55:00  14.156582
# 2023-11-09 04:56:00  24.231129
# 2023-11-09 04:57:00  11.464312
# 2023-11-09 04:58:00  10.224547
# 2023-11-09 04:59:00  49.804823

# %%
exchange.fetch_order_book(symbol, params={})

# %% [markdown]
# # Archived code for using async ccxt

# %%
# This is failing for some reason

exchange = ccxt.coinbasepro(
    {
        "apiKey": coinbase_pro_api_key,
        "secret": coinbase_pro_api_secret,
        "password": coinbase_pro_api_password,
        "enableRateLimit": True,
    }
)

symbol = "ETH/USD"


async def fetch(exchange, page):
    try:
        trades = await exchange.fetch_trades(symbol, params={"after": page})
    except ccxt.RateLimitExceeded as e:
        print("Sleeping")
        await exchange.sleep(10000)
        return await fetch(exchange, page)
    except Exception as e:
        raise e


async def fetch_all(exchange, symbol):
    # Determine how to batch async requests
    trades = await exchange.fetch_trades(symbol)

    # Let's try to do like 10% of the expected pages at a time?
    since = exchange.parse8601("2023-11-09T00:00:00Z")
    expected_range = trades[-1]["timestamp"] - trades[0]["timestamp"]
    requested_range = trades[-1]["timestamp"] - since
    expected_pages = int(requested_range / expected_range)

    batch_size = min(2000, expected_pages)

    first_page = int(exchange.last_response_headers.get("Cb-After"))
    pages = [first_page - 1000 * step for step in range(batch_size)]

    tasks = (asyncio.create_task(fetch(exchange, page)) for page in pages)
    results = await asyncio.gather(*tasks)
    return results


async def main():
    results = await fetch_all(exchange, symbol)
    print(results)
    return results


results = await main()
await exchange.close()
